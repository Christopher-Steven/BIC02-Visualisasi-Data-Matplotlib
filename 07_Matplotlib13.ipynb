# %% [markdown]
# ## Pertemuan 07 Matplotlib 13
# - ### Sumber : https://youtu.be/uXybJxtxl5s
# - ### membuat 3D Plotting

# %%
# %matplotlib notebook

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.3.2
# 1.19.2

# %% [markdown]
# ### 3D Axes

# %%
fig = plt.figure()
ax = plt.axes(projection ='3d')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# - cara membuat 3D Axes
# > 1. membangun figurenya dulu dengan cara `figure()`
# > 2. membentuk project axesnya `axes(projection='3d')`
# > 3. `projection='3d'` digunakann untuk membuat project 3Dnya

# %% [markdown]
# ### 3D Line Plot

# %%
z = np.linspace(0,1,100)
x = z* np.sin(20*z)
y = z* np.cos(20*z)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot(x,y,z,color='red')

ax.set(title='contoh 3D Line Plot',
      xlabel = 'sumbu X',
      ylabel = 'sumbu Y',
      zlabel = 'sumbu z')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# - `linspace(val_min,val_max,val_sumdata)`
# > - parameter kesatu digunakan untuk memberikan value minimum
# > - parameter kedua digunakan untuk meberikan value maksimum
# > - parameter ketiga digunakan untuk menentukan banyak data.
# - cara membuat 3D Line Plot
# > 1. membangun figurenya dulu dengan cara `figure()`
# > 2. membentuk project axesnya `axes(projection='3d')`
# > 3. `projection='3d'` digunakann untuk membuat project 3Dnya
# > 4. menggunakan `plot(var_x,var_y,var_z,color='val_color')` untuk membuat line plot dalam bentuk 3D. Fungsi `plot()` ini digunakan untuk membuat line atau garis pada saat menggambarkan 3Dnya.
# >> - parameter kesatu digunakan untuk memberikan value sumbu x
# >> - parameter kedua digunakan untuk memberikan value sumbu y
# >> - parameter ketiga digunakan untuk memberikan value sumbu z
# >> - parameter keempat digunakan untuk memberikan warna pada plotnya.

# %% [markdown]
# ### 3D Scatter Plot

# %%
z = np.linspace(0,1,100)
x = z* np.sin(20*z)
y = z* np.cos(20*z)

# %%
fig = plt.figure()
ax = plt.axes(projection ='3d')
ax.scatter(x,y,z,color ='green')
ax.set(title='Contoh 3D Scatter Plot',
      xlabel='Sumbu X',
      ylabel='Sumbu Y',
      zlabel='Sumbu Z')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# - cara membuat 3D Scatter Plot
# > 1. membangun figurenya dulu dengan cara `figure()`
# > 2. membentuk project axesnya `axes(projection='3d')`
# > 3. `projection='3d'` digunakann untuk membuat project 3Dnya
# > 4. megguakan `scatter(var_x,var_y,var_z,color='val_color')` untuk membuat 3D scatter plot, penggunaann fungsi `scatter()` digunakan untuk membuat sebuah plot dalam bentuk dot atau titik.
# >> - parameter kesatu digunakan untuk memberikan value sumbu x
# >> - parameter kedua digunakan untuk memberikan value sumbu y
# >> - parameter ketiga digunakan untuk memberikan value sumbu z
# >> - parameter keempat digunakan untuk memberikan warna pada plotnya.
